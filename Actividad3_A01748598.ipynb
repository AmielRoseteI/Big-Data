# %% [markdown]
# # Filtrado por Particionamiento en Retrasos Aéreos

# %% [markdown]
# Descripción de la base de datos D
# La base de datos contiene información sobre vuelos realizados en los Estados Unidos. Entre sus atributos se encuentran el mes del vuelo (Month), la aerolínea (Airline), y si el vuelo tuvo un retraso de 15 minutos o más en su salida (DepDel15). Esta base se utilizará para analizar la probabilidad de retrasos y construir conjuntos de entrenamiento y prueba basados en reglas de particionamiento.

# %% [markdown]
# ##**Introducción**
# ###**Aprendizaje Supervisado**
#
# El aprendizaje supervisado es un tipo de aprendizaje automático donde un modelo es entrenado utilizando un conjunto de datos etiquetado. El objetivo es predecir la salida de datos nuevos basándose en las etiquetas aprendidas. Algunos algoritmos representativos incluyen:
#
# **-Decision Tree:** Un modelo de árbol que toma decisiones en función de características.
#
# **-Random Forest:** Un conjunto de árboles de decisión que mejora la precisión y evita el sobreajuste.
#
# **Gradient Boosted Trees (GBT):** Un algoritmo que construye árboles de decisión en secuencia, corrigiendo errores de árboles anteriores.
#
# **Multilayer Perceptron:** Una red neuronal de múltiples capas que puede aprender relaciones complejas.
#
# Todos estos algoritmos están disponibles en el módulo **pyspark.ml.classification.**
#
# ###**Aprendizaje No Supervisado**
#
#
# El aprendizaje no supervisado es un tipo de aprendizaje automático donde el modelo es entrenado con datos que no están etiquetados. El objetivo es encontrar patrones o agrupaciones en los datos. Algunos algoritmos representativos incluyen:
#
# **-K-Means:** Un algoritmo de agrupamiento que divide los datos en K grupos.
#
# **-Gaussian Mixture Model:** Un modelo probabilístico que asume que los datos provienen de una mezcla de distribuciones Gaussianas.
#
# **Principal Component Analysis (PCA):** Un método para reducir la dimensionalidad de los datos.
#
# Estos algoritmos están disponibles en el módulo **pyspark.ml.clustering**

# %% [markdown]
# ### Cargando el entorno de PySpark en Goolge Colab

# %%
#import os
#os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
#os.environ["SPARK_HOME"] = "/content/spark-3.1.1-bin-hadoop3.2"

# %%
# !pip install findspark
import findspark
findspark.init()
from pyspark import SparkContext, SparkConf, SQLContext
from pyspark.sql import SparkSession
#spark = SparkSession.builder.master("local[*]").getOrCreate()
spark = SparkSession.builder \
                    .master("local[*]") \
                    .appName("Ejemplo") \
                    .getOrCreate()
spark.conf.set("spark.sql.repl.eagerEval.enabled", True) # Property used to format output tables better
spark
# Out:
# Requirement already satisfied: findspark in /usr/local/lib/python3.11/dist-packages (2.0.1)
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://dce18090fa5c:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Ejemplo</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## Creando un Dataframe a partir de un archivo "csv" de entrada

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = spark.read.csv('/content/drive/MyDrive/Big Data/Copia de Combined_Flights_2022.csv', header=True, sep=",", inferSchema=True)
#Visualización limitada a los primeros 10 registros
df.show(10)
# Out:
# +----------+--------------------+------+----+---------+--------+----------+-------+---------------+--------+-------+---------------+-------+--------------+-----------------+--------+----+-------+-----+----------+---------+-------------------------+---------------------------------------+------------------------+---------------------------+-------------------------------+-----------------+------------------------+---------------------------+-----------+-------------------------------+---------------+------------------+------------------+--------------------+-----------+---------------+---------------+---------+-------------+----------------+----------------+-------------------+---------+-------------+-------------+-------+--------+--------------------+----------+-------+---------+--------+------+----------+--------+--------+------------------+----------+-------------+------------------+
# |FlightDate|             Airline|Origin|Dest|Cancelled|Diverted|CRSDepTime|DepTime|DepDelayMinutes|DepDelay|ArrTime|ArrDelayMinutes|AirTime|CRSElapsedTime|ActualElapsedTime|Distance|Year|Quarter|Month|DayofMonth|DayOfWeek|Marketing_Airline_Network|Operated_or_Branded_Code_Share_Partners|DOT_ID_Marketing_Airline|IATA_Code_Marketing_Airline|Flight_Number_Marketing_Airline|Operating_Airline|DOT_ID_Operating_Airline|IATA_Code_Operating_Airline|Tail_Number|Flight_Number_Operating_Airline|OriginAirportID|OriginAirportSeqID|OriginCityMarketID|      OriginCityName|OriginState|OriginStateFips|OriginStateName|OriginWac|DestAirportID|DestAirportSeqID|DestCityMarketID|       DestCityName|DestState|DestStateFips|DestStateName|DestWac|DepDel15|DepartureDelayGroups|DepTimeBlk|TaxiOut|WheelsOff|WheelsOn|TaxiIn|CRSArrTime|ArrDelay|ArrDel15|ArrivalDelayGroups|ArrTimeBlk|DistanceGroup|DivAirportLandings|
# +----------+--------------------+------+----+---------+--------+----------+-------+---------------+--------+-------+---------------+-------+--------------+-----------------+--------+----+-------+-----+----------+---------+-------------------------+---------------------------------------+------------------------+---------------------------+-------------------------------+-----------------+------------------------+---------------------------+-----------+-------------------------------+---------------+------------------+------------------+--------------------+-----------+---------------+---------------+---------+-------------+----------------+----------------+-------------------+---------+-------------+-------------+-------+--------+--------------------+----------+-------+---------+--------+------+----------+--------+--------+------------------+----------+-------------+------------------+
# |2022-04-04|Commutair Aka Cha...|   GJT| DEN|    false|   false|      1133| 1123.0|            0.0|   -10.0| 1228.0|            0.0|   40.0|          72.0|             65.0|   212.0|2022|      2|    4|         4|        1|                       UA|                           UA_CODESHARE|                   19977|                         UA|                           4301|               C5|                   20445|                         C5|     N21144|                           4301|          11921|           1192102|             31921|  Grand Junction, CO|         CO|              8|       Colorado|       82|        11292|         1129202|           30325|         Denver, CO|       CO|            8|     Colorado|     82|     0.0|                -1.0| 1100-1159|   17.0|   1140.0|  1220.0|   8.0|      1245|   -17.0|     0.0|              -2.0| 1200-1259|            1|                 0|
# |2022-04-04|Commutair Aka Cha...|   HRL| IAH|    false|   false|       732|  728.0|            0.0|    -4.0|  848.0|            0.0|   55.0|          77.0|             80.0|   295.0|2022|      2|    4|         4|        1|                       UA|                           UA_CODESHARE|                   19977|                         UA|                           
          12266|           1226603|             31453|         Houston, TX|         TX|             48|          Texas|       74|        10185|         1018502|           30185|     Alexandria, LA|       LA|           22|    Louisiana|     72|     0.0|                -1.0| 1400-1459|   16.0|   1430.0|  1507.0|   6.0|      1524|   -11.0|     0.0|              -1.0| 1500-1559|            1|                 0|
# |2022-04-04|Commutair Aka Cha...|   IAH| MOB|    false|   false|       954|  947.0|            0.0|    -7.0| 1110.0|            0.0|   60.0|          87.0|             83.0|   427.0|2022|      2|    4|         4|        1|                       UA|                           UA_CODESHARE|                   19977|                         UA|                           4290|               C5|                   20445|                         C5|     N21154|                           4290|          12266|           1226603|             31453|         Houston, TX|         TX|             48|          Texas|       74|        13422|         1342202|           30562|         Mobile, AL|       AL|            1|      Alabama|     51|     0.0|                -1.0| 0900-0959|   17.0|   1004.0|  1104.0|   6.0|      1121|   -11.0|     0.0|              -1.0| 1100-1159|            2|                 0|
# +----------+--------------------+------+----+---------+--------+----------+-------+---------------+--------+-------+---------------+-------+--------------+-----------------+--------+----+-------+-----+----------+---------+-------------------------+---------------------------------------+------------------------+---------------------------+-------------------------------+-----------------+------------------------+---------------------------+-----------+-------------------------------+---------------+------------------+------------------+--------------------+-----------+---------------+---------------+---------+-------------+----------------+----------------+-------------------+---------+-------------+-------------+-------+--------+--------------------+----------+-------+---------+--------+------+----------+--------+--------+------------------+----------+-------------+------------------+
# only showing top 10 rows

# %%
# Imprimiendo en número de registros en el Dataframe
df.count()
# Out:
# 4078318

# %%
# Imprimiendo el número de columnas en el Dataframe
print(len(df.columns))
# Out:
# 61

# %% [markdown]
# #### Imprimiendo información sobre el tipo de datos y esquema del Dataframe

# %%
# Imprimiendo los tipos de datos del Dataframe
df.dtypes
# Out:
# [('FlightDate', 'date'),
#  ('Airline', 'string'),
#  ('Origin', 'string'),
#  ('Dest', 'string'),
#  ('Cancelled', 'boolean'),
#  ('Diverted', 'boolean'),
#  ('CRSDepTime', 'int'),
#  ('DepTime', 'double'),
#  ('DepDelayMinutes', 'double'),
#  ('DepDelay', 'double'),
#  ('ArrTime', 'double'),
#  ('ArrDelayMinutes', 'double'),
#  ('AirTime', 'double'),
#  ('CRSElapsedTime', 'double'),
#  ('ActualElapsedTime', 'double'),
#  ('Distance', 'double'),
#  ('Year', 'int'),
#  ('Quarter', 'int'),
#  ('Month', 'int'),
#  ('DayofMonth', 'int'),
#  ('DayOfWeek', 'int'),
#  ('Marketing_Airline_Network', 'string'),
#  ('Operated_or_Branded_Code_Share_Partners', 'string'),
#  ('DOT_ID_Marketing_Airline', 'int'),
#  ('IATA_Code_Marketing_Airline', 'string'),
#  ('Flight_Number_Marketing_Airline', 'int'),
#  ('Operating_Airline', 'string'),
#  ('DOT_ID_Operating_Airline', 'int'),
#  ('IATA_Code_Operating_Airline', 'string'),
#  ('Tail_Number', 'string'),
#  ('Flight_Number_Operating_Airline', 'int'),
#  ('OriginAirportID', 'int'),
#  ('OriginAirportSeqID', 'int'),
#  ('OriginCityMarketID', 'int'),
#  ('OriginCityName', 'string'),
#  ('OriginState', 'string'),
#  ('OriginStateFips', 'int'),
#  ('OriginStateName', 'string'),
#  ('OriginWac', 'int'),
#  ('DestAirportID', 'int'),
#  ('DestAirportSeqID', 'int'),
#  ('DestCityMarketID', 'int'),
#  ('DestCityName', 'string'),
#  ('DestState', 'string'),
#  ('DestStateFips', 'int'),
#  ('DestStateName', 'string'),
#  ('DestWac', 'int'),
#  ('DepDel15', 'double'),
#  ('DepartureDelayGroups', 'double'),
#  ('DepTimeBlk', 'string'),
#  ('TaxiOut', 'double'),
#  ('WheelsOff', 'double'),
#  ('WheelsOn', 'double'),
#  ('TaxiIn', 'double'),
#  ('CRSArrTime', 'int'),
#  ('ArrDelay', 'double'),
#  ('ArrDel15', 'double'),
#  ('ArrivalDelayGroups', 'double'),
#  ('ArrTimeBlk', 'string'),
#  ('DistanceGroup', 'int'),
#  ('DivAirportLandings', 'int')]

# %%
# Imprimiendo el esquema del Dataframe
df.printSchema()
# Out:
# root
#  |-- FlightDate: date (nullable = true)
#  |-- Airline: string (nullable = true)
#  |-- Origin: string (nullable = true)
#  |-- Dest: string (nullable = true)
#  |-- Cancelled: boolean (nullable = true)
#  |-- Diverted: boolean (nullable = true)
#  |-- CRSDepTime: integer (nullable = true)
#  |-- DepTime: double (nullable = true)
#  |-- DepDelayMinutes: double (nullable = true)
#  |-- DepDelay: double (nullable = true)
#  |-- ArrTime: double (nullable = true)
#  |-- ArrDelayMinutes: double (nullable = true)
#  |-- AirTime: double (nullable = true)
#  |-- CRSElapsedTime: double (nullable = true)
#  |-- ActualElapsedTime: double (nullable = true)
#  |-- Distance: double (nullable = true)
#  |-- Year: integer (nullable = true)
#  |-- Quarter: integer (nullable = true)
#  |-- Month: integer (nullable = true)
#  |-- DayofMonth: integer (nullable = true)
#  |-- DayOfWeek: integer (nullable = true)
#  |-- Marketing_Airline_Network: string (nullable = true)
#  |-- Operated_or_Branded_Code_Share_Partners: string (nullable = true)
#  |-- DOT_ID_Marketing_Airline: integer (nullable = true)
#  |-- IATA_Code_Marketing_Airline: string (nullable = true)
#  |-- Flight_Number_Marketing_Airline: integer (nullable = true)
#  |-- Operating_Airline: string (nullable = true)
#  |-- DOT_ID_Operating_Airline: integer (nullable = true)
#  |-- IATA_Code_Operating_Airline: string (nullable = true)
#  |-- Tail_Number: string (nullable = true)
#  |-- Flight_Number_Operating_Airline: integer (nullable = true)
#  |-- OriginAirportID: integer (nullable = true)
#  |-- OriginAirportSeqID: integer (nullable = true)
#  |-- OriginCityMarketID: integer (nullable = true)
#  |-- OriginCityName: string (nullable = true)
#  |-- OriginState: string (nullable = true)
#  |-- OriginStateFips: integer (nullable = true)
#  |-- OriginStateName: string (nullable = true)
#  |-- OriginWac: integer (nullable = true)
#  |-- DestAirportID: integer (nullable = true)
#  |-- DestAirportSeqID: integer (nullable = true)
#  |-- DestCityMarketID: integer (nullable = true)
#  |-- DestCityName: string (nullable = true)
#  |-- DestState: string (nullable = true)
#  |-- DestStateFips: integer (nullable = true)
#  |-- DestStateName: string (nullable = true)
#  |-- DestWac: integer (nullable = true)
#  |-- DepDel15: double (nullable = true)
#  |-- DepartureDelayGroups: double (nullable = true)
#  |-- DepTimeBlk: string (nullable = true)
#  |-- TaxiOut: double (nullable = true)
#  |-- WheelsOff: double (nullable = true)
#  |-- WheelsOn: double (nullable = true)
#  |-- TaxiIn: double (nullable = true)
#  |-- CRSArrTime: integer (nullable = true)
#  |-- ArrDelay: double (nullable = true)
#  |-- ArrDel15: double (nullable = true)
#  |-- ArrivalDelayGroups: double (nullable = true)
#  |-- ArrTimeBlk: string (nullable = true)
#  |-- DistanceGroup: integer (nullable = true)
#  |-- DivAirportLandings: integer (nullable = true)

# %% [markdown]
# ## Encontrando Probabilidades en Conjunto

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, count, lit, round, sum as spark_sum

# Start Spark session
spark = SparkSession.builder.appName("JointProbabilityPivot").getOrCreate()

# STEP 1: Count combinations of Airline and DepDel15
joint_counts = df.groupBy("Month", "DepDel15").count()

# STEP 2: Get total number of rows
total_count = df.count()

# STEP 3: Calculate joint probability
joint_prob = joint_counts.withColumn("probability", col("count") / lit(total_count))

# STEP 4: Pivot the table so each DepDel15 value is a column
pivoted_prob = joint_prob.groupBy("Month").pivot("DepDel15").agg(round(spark_sum("probability"), 6))

# Rename columns for clarity
pivoted_prob = pivoted_prob \
    .withColumnRenamed("0.0", "P(DepDel15=0)") \
    .withColumnRenamed("1.0", "P(DepDel15=1)")

sorted_result = pivoted_prob.filter(col("P(DepDel15=1)").isNotNull()) \
                            .orderBy(col("P(DepDel15=1)").desc())
sorted_result.show(n = 1000,truncate=False)
# Out:
# +-----+--------+-------------+-------------+
# |Month|null    |P(DepDel15=0)|P(DepDel15=1)|
# +-----+--------+-------------+-------------+
# |7    |0.002653|0.113488     |0.035586     |
# |6    |0.004378|0.108008     |0.035238     |
# |4    |0.003198|0.108382     |0.030706     |
# |5    |0.002842|0.114389     |0.030612     |
# |3    |0.002154|0.112252     |0.030394     |
# |1    |0.008652|0.1041       |0.025476     |
# |2    |0.005668|0.097827     |0.023996     |
# +-----+--------+-------------+-------------+

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, count, lit, round, sum as spark_sum

# Start Spark session
spark = SparkSession.builder.appName("JointProbabilityPivot").getOrCreate()

# STEP 1: Count combinations of Airline and DepDel15
joint_counts = df.groupBy("Airline", "DepDel15").count()

# STEP 2: Get total number of rows
total_count = df.count()

# STEP 3: Calculate joint probability
joint_prob = joint_counts.withColumn("probability", col("count") / lit(total_count))

# STEP 4: Pivot the table so each DepDel15 value is a column
pivoted_prob = joint_prob.groupBy("Airline").pivot("DepDel15").agg(round(spark_sum("probability"), 6))

# Rename columns for clarity
pivoted_prob = pivoted_prob \
    .withColumnRenamed("0.0", "P(DepDel15=0)") \
    .withColumnRenamed("1.0", "P(DepDel15=1)")

sorted_result = pivoted_prob.filter(col("P(DepDel15=1)").isNotNull()) \
                            .orderBy(col("P(DepDel15=1)").desc())
sorted_result.show(n = 1000,truncate=False)
# Out:
# +-----------------------------------------+--------+-------------+-------------+
# |Airline                                  |null    |P(DepDel15=0)|P(DepDel15=1)|
# +-----------------------------------------+--------+-------------+-------------+
# |Southwest Airlines Co.                   |0.004423|0.12355      |0.051494     |
# |American Airlines Inc.                   |0.004476|0.091394     |0.025737     |
# |Delta Air Lines Inc.                     |0.00249 |0.100681     |0.022399     |
# |United Air Lines Inc.                    |0.00194 |0.066127     |0.018246     |
# |SkyWest Airlines Inc.                    |0.002233|0.088733     |0.017119     |
# |JetBlue Airways                          |0.001827|0.023981     |0.012638     |
# |Republic Airlines                        |0.00272 |0.037218     |0.008582     |
# |Spirit Air Lines                         |0.001005|0.022854     |0.007823     |
# |Frontier Airlines Inc.                   |5.94E-4 |0.014144     |0.006486     |
# |Comair Inc.                              |0.001265|0.025586     |0.006468     |
# |Allegiant Air                            |7.03E-4 |0.011798     |0.005522     |
# |Envoy Air                                |9.22E-4 |0.030534     |0.00551      |
# |Alaska Airlines Inc.                     |8.91E-4 |0.025568     |0.005296     |
# |Endeavor Air Inc.                        |0.001393|0.028645     |0.004933     |
# |Mesa Airlines Inc.                       |7.15E-4 |0.013623     |0.003309     |
# |Horizon Air                              |2.25E-4 |0.011565     |0.002019     |
# |Commutair Aka Champlain Enterprises, Inc.|3.65E-4 |0.008642     |0.001871     |
# |GoJet Airlines, LLC d/b/a United Express |5.82E-4 |0.006122     |0.001827     |
# |Capital Cargo International              |3.48E-4 |0.01093      |0.001675     |
# |Hawaiian Airlines Inc.                   |8.6E-5  |0.008615     |0.00165      |
# |Air Wisconsin Airlines Corp              |3.43E-4 |0.008135     |0.001404     |
# +-----------------------------------------+--------+-------------+-------------+

# %%
# Caso 2: agrupando valores a partir de dos columnas
df_grouped = df.groupBy('Airline', 'Month', 'DepDel15').count()
df_grouped.show(n = 1000,truncate=False)
# Out:
# +-----------------------------------------+-----+--------+-----+
# |Airline                                  |Month|DepDel15|count|
# +-----------------------------------------+-----+--------+-----+
# |Envoy Air                                |4    |0.0     |18082|
# |Envoy Air                                |4    |1.0     |3372 |
# |Endeavor Air Inc.                        |4    |NULL    |200  |
# |Endeavor Air Inc.                        |4    |0.0     |17575|
# |JetBlue Airways                          |4    |NULL    |2125 |
# |Alaska Airlines Inc.                     |4    |0.0     |14662|
# |Mesa Airlines Inc.                       |4    |0.0     |8824 |
# |American Airlines Inc.                   |4    |NULL    |1293 |
# |GoJet Airlines, LLC d/b/a United Express |4    |0.0     |3500 |
# |Frontier Airlines Inc.                   |4    |0.0     |7356 |
# |Allegiant Air                            |4    |NULL    |309  |
# |Delta Air Lines Inc.                     |4    |1.0     |13296|
# |Alaska Airlines Inc.                     |4    |NULL    |1048 |
# |Capital Cargo International              |4    |1.0     |722  |
# |Commutair Aka Champlain Enterprises, Inc.|4    |1.0     |800  |
# |American Airlines Inc.                   |4    |0.0     |52611|
# |Southwest Airlines Co.                   |4    |NULL    |1912 |
# |Air Wisconsin Airlines Corp              |4    |NULL    |132  |
# |Frontier Airlines Inc.                   |4    |1.0     |4423 |
# |GoJet Airlines, LLC d/b/a United Express |4    |1.0     |990  |
# |Hawaiian Airlines Inc.                   |4    |1.0     |1007 |
# |Mesa Airlines Inc.                       |4    |NULL    |103  |
# |Delta Air Lines Inc.                     |4    |0.0     |58996|
# |Southwest Airlines Co.                   |4    |0.0     |68092|
# |Frontier Airlines Inc.                   |4    |NULL    |424  |
# |SkyWest Airlines Inc.                    |4    |1.0     |8927 |
# |Mesa Airlines Inc.                       |4    |1.0     |1442 |
# |Hawaiian Airlines Inc.                   |4    |0.0     |4930 |
# |Envoy Air                                |4    |NULL    |315  |
# |JetBlue Airways                          |4    |0.0     |12514|
# |Allegiant Air                            |4    |0.0     |6777 |
# |Republic Airlines                        |4    |0.0     |24484|
# |JetBlue Airways                          |4    |1.0     |9502 |
# |Republic Airlines                        |4    |NULL    |611  |
# |Endeavor Air Inc.                        |4    |1.0     |2491 |
# |Commutair Aka Champlain Enterprises, Inc.|4    |0.0     |4888 |
# |Air Wisconsin Airlines Corp              |4    |0.0     |5159 |
# |Capital Cargo International              |4    |NULL    |35   |
# |Southwest Airlines Co.                   |4    |1.0     |32927|
# |Delta Air Lines Inc.                     |4    |NULL    |784  |
# |Commutair Aka Champlain Enterprises, Inc.|4    |NULL    |87   |
# |Air Wisconsin Airlines Corp              |4    |1.0     |704  |
# |GoJet Airlines, LLC d/b/a United Express |4    |NULL    |145  |
# |Republic Airlines                        |4    |1.0     |4870 |
# |Capital Cargo International              |4    |0.0     |6643 |
# |American Airlines Inc.                   |4    |1.0     |13273|
# |Alaska Airlines Inc.                     |4    |1.0     |3651 |
# |Allegiant Air                            |4    |1.0     |3456 |
# |Hawaiian Airlines Inc.                   |4    |NULL    |82   |
# |Endeavor Air Inc.                        |2    |0.0     |15683|
# |Comair Inc.                              |4    |1.0     |3196 |
# |Comair Inc.                              |4    |0.0     |15827|
# |Southwest Airlines Co.                   |2    |1.0     |20326|
# |Horizon Air                              |2    |1.0     |881  |
# |Spirit Air Lines                         |4    |1.0     |5403 |
# |United Air Lines Inc.                    |4    |1.0     |9589 |
# |Horizon Air                              |4    |0.0     |6391 |
# |Southwest Airlines Co.                   |2    |NULL    |3767 |
# |Horizon Air                              |2    |NULL    |92   |
# |American Airlines Inc.                   |2    |0.0     |47968|
# |American Airlines Inc.                   |2    |1.0     |11590|
# |Comair Inc.                              |4    |NULL    |166  |
# |SkyWest Airlines Inc.                    |2    |NULL    |2177 |
# |SkyWest Airlines Inc.                    |2    |1.0     |9497 |
# |Spirit Air Lines                         |4    |0.0     |11357|
# |Horizon Air                              |2    |0.0     |6053 |
# |United Air Lines Inc.                    |4    |NULL    |462  |
# |Southwest Airlines Co.                   |2    |0.0     |66872|
# |Horizon Air                              |4    |1.0     |1189 |
# |Endeavor Air Inc.                        |2    |NULL    |760  |
# |Spirit Air Lines                         |4    |NULL    |1893 |
# |American Airlines Inc.                   |2    |NULL    |5309 |
# |United Air Lines Inc.                    |4    |0.0     |39201|
# |Endeavor Air Inc.                        |2    |1.0     |2515 |
# |SkyWest Airlines Inc.                    |4    |NULL    |765  |
# |SkyWest Airlines Inc.                    |4    |0.0     |54149|
# |SkyWest Airlines Inc.                    |2    |0.0     |43275|
# |Horizon Air                              |4    |NULL    |151  |
# |Spirit Air Lines                         |2    |NULL    |552  |
# |Capital Cargo International              |2    |1.0     |1024 |
# |Spirit Air Lines                         |2    |1.0     |3915 |
# |Alaska Airlines Inc.                     |2    |1.0     |2225 |
# |Comair Inc.                              |2    |1.0     |3840 |
# |Comair Inc.                              |7    |1.0     |4187 |
# |Comair Inc.                              |7    |0.0     |14446|
# |SkyWest Airlines Inc.                    |7    |0.0     |54748|
# |Allegiant Air                            |2    |0.0     |5932 |
# |Envoy Air                                |2    |1.0     |3109 |
# |Air Wisconsin Airlines Corp              |2    |0.0     |4383 |
# |United Air Lines Inc.                    |2    |NULL    |870  |
# |Republic Airlines                        |2    |0.0     |19039|
# |SkyWest Airlines Inc.                    |7    |1.0     |9992 |
# |Delta Air Lines Inc.                     |2    |NULL    |877  |
# |JetBlue Airways                          |2    |1.0     |6831 |
# |GoJet Airlines, LLC d/b/a United Express |2    |NULL    |463  |
# |Comair Inc.                              |2    |0.0     |14413|
# |Allegiant Air                            |2    |NULL    |483  |
# |Commutair Aka Champlain Enterprises, Inc.|2    |NULL    |494  |
# |United Air Lines Inc.                    |2    |1.0     |8708 |
# |United Air Lines Inc.                    |2    |0.0     |34404|
# |Mesa Airlines Inc.                       |2    |0.0     |7371 |
# |Spirit Air Lines                         |2    |0.0     |12262|
# |Envoy Air                                |2    |0.0     |15619|
# |Comair Inc.                              |7    |NULL    |521  |
# |Republic Airlines                        |2    |1.0     |4144 |
# |Frontier Airlines Inc.                   |2    |NULL    |479  |
# |Hawaiian Airlines Inc.                   |2    |1.0     |561  |
# |SkyWest Airlines Inc.                    |7    |NULL    |486  |
# |Mesa Airlines Inc.                       |2    |1.0     |1837 |
# |Commutair Aka Champlain Enterprises, Inc.|2    |1.0     |1009 |
# |Frontier Airlines Inc.                   |2    |1.0     |2993 |
# |Hawaiian Airlines Inc.                   |2    |0.0     |4412 |
# |Envoy Air                                |2    |NULL    |2034 |
# |Capital Cargo International              |2    |NULL    |355  |
# |Air Wisconsin Airlines Corp              |2    |NULL    |377  |
# |Mesa Airlines Inc.                       |2    |NULL    |672  |
# |Delta Air Lines Inc.                     |2    |0.0     |53263|
# |Alaska Airlines Inc.                     |2    |0.0     |13520|
# |Allegiant Air                            |2    |1.0     |2257 |
# |Capital Cargo International              |2    |0.0     |6471 |
# |Frontier Airlines Inc.                   |2    |0.0     |7659 |
# |Alaska Airlines Inc.                     |2    |NULL    |224  |
# |Delta Air Lines Inc.                     |2    |1.0     |8615 |
# |GoJet Airlines, LLC d/b/a United Express |2    |1.0     |1068 |
# |Hawaiian Airlines Inc.                   |2    |NULL    |11   |
# |Republic Airlines                        |2    |NULL    |1452 |
# |JetBlue Airways                          |2    |0.0     |12720|
# |Air Wisconsin Airlines Corp              |2    |1.0     |919  |
# |JetBlue Airways                          |2    |NULL    |1028 |
# |Comair Inc.                              |2    |NULL    |641  |
# |GoJet Airlines, LLC d/b/a United Express |2    |0.0     |3417 |
# |Commutair Aka Champlain Enterprises, Inc.|2    |0.0     |4235 |
# |Mesa Airlines Inc.                       |7    |0.0     |7344 |
# |Horizon Air                              |5    |NULL    |65   |
# |Commutair Aka Champlain Enterprises, Inc.|5    |0.0     |5022 |
# |Horizon Air                              |5    |0.0     |7055 |
# |Endeavor Air Inc.                        |5    |NULL    |597  |
# |Mesa Airlines Inc.                       |7    |NULL    |182  |
# |United Air Lines Inc.                    |5    |NULL    |981  |
# |American Airlines Inc.                   |5    |0.0     |55586|
# |Republic Airlines                        |7    |NULL    |1157 |
# |Mesa Airlines Inc.                       |7    |1.0     |2060 |
# |Commutair Aka Champlain Enterprises, Inc.|5    |NULL    |89   |
# |United Air Lines Inc.                    |5    |0.0     |41417|
# |GoJet Airlines, LLC d/b/a United Express |5    |NULL    |347  |
# |Comair Inc.                              |5    |1.0     |3617 |
# |Air Wisconsin Airlines Corp              |5    |NULL    |84   |
# |Endeavor Air Inc.                        |5    |1.0     |2843 |
# |GoJet Airlines, LLC d/b/a United Express |5    |1.0     |1285 |
# |Horizon Air                              |5    |1.0     |1158 |
# |United Air Lines Inc.                    |5    |1.0     |11248|
# |American Airlines Inc.                   |5    |NULL    |1102 |
# |Air Wisconsin Airlines Corp              |5    |0.0     |5132 |
# |Southwest Airlines Co.                   |7    |0.0     |76275|
# |SkyWest Airlines Inc.                    |5    |1.0     |9703 |
# |Comair Inc.                              |5    |0.0     |15137|
# |Southwest Airlines Co.                   |7    |NULL    |1836 |
# |Republic Airlines                        |7    |0.0     |21002|
# |Air Wisconsin Airlines Corp              |5    |1.0     |697  |
# |GoJet Airlines, LLC d/b/a United Express |5    |0.0     |3428 |
# |SkyWest Airlines Inc.                    |5    |0.0     |56464|
# |JetBlue Airways                          |5    |0.0     |16102|
# |Frontier Airlines Inc.                   |5    |1.0     |4083 |
# |Spirit Air Lines                         |5    |1.0     |5180 |
# |Republic Airlines                        |5    |0.0     |22324|
# |Mesa Airlines Inc.                       |5    |0.0     |8698 |
# |Capital Cargo International              |5    |0.0     |6191 |
# |Spirit Air Lines                         |5    |0.0     |13510|
# |Frontier Airlines Inc.                   |5    |NULL    |161  |
# |Allegiant Air                            |5    |NULL    |179  |
# |Delta Air Lines Inc.                     |5    |1.0     |13320|
# |Capital Cargo International              |5    |1.0     |808  |
# |Frontier Airlines Inc.                   |5    |0.0     |8434 |
# |Delta Air Lines Inc.                     |5    |0.0     |60789|
# |Capital Cargo International              |5    |NULL    |93   |
# |Southwest Airlines Co.                   |5    |0.0     |78471|
# |Mesa Airlines Inc.                       |5    |1.0     |2103 |
# |Hawaiian Airlines Inc.                   |5    |1.0     |829  |
# |Alaska Airlines Inc.                     |5    |NULL    |648  |
# |Southwest Airlines Co.                   |5    |1.0     |28771|
# |Hawaiian Airlines Inc.                   |5    |NULL    |4    |
# |Republic Airlines                        |5    |NULL    |1861 |
# |Envoy Air                                |5    |1.0     |3329 |
# |Mesa Airlines Inc.                       |5    |NULL    |236  |
# |JetBlue Airways                          |5    |1.0     |6984 |
# |Spirit Air Lines                         |5    |NULL    |399  |
# |Southwest Airlines Co.                   |6    |1.0     |35972|
# |Comair Inc.                              |1    |NULL    |2192 |
# |Mesa Airlines Inc.                       |6    |0.0     |7515 |
# |Comair Inc.                              |1    |1.0     |3925 |
# |JetBlue Airways                          |6    |0.0     |13104|
# |Hawaiian Airlines Inc.                   |1    |1.0     |1023 |
# |Endeavor Air Inc.                        |1    |1.0     |2814 |
# |Frontier Airlines Inc.                   |1    |1.0     |3137 |
# |Capital Cargo International              |6    |0.0     |5979 |
# |Endeavor Air Inc.                        |1    |0.0     |17514|
# |Envoy Air                                |1    |NULL    |649  |
# |Republic Airlines                        |6    |NULL    |2370 |
# |Envoy Air                                |1    |0.0     |18542|
# |Envoy Air                                |1    |1.0     |3014 |
# |Delta Air Lines Inc.                     |1    |0.0     |56638|
# |Alaska Airlines Inc.                     |6    |0.0     |15516|
# |Mesa Airlines Inc.                       |6    |NULL    |182  |
# |American Airlines Inc.                   |6    |1.0     |21714|
# |Allegiant Air                            |1    |0.0     |5976 |
# |Alaska Airlines Inc.                     |6    |NULL    |147  |
# |Horizon Air                              |1    |1.0     |1764 |
# |JetBlue Airways                          |6    |NULL    |709  |
# |Allegiant Air                            |1    |NULL    |717  |
# |Allegiant Air                            |1    |1.0     |2021 |
# |Southwest Airlines Co.                   |1    |NULL    |6439 |
# |Spirit Air Lines                         |1    |0.0     |13336|
# |Spirit Air Lines                         |1    |NULL    |591  |
# |Hawaiian Airlines Inc.                   |1    |NULL    |217  |
# |Frontier Airlines Inc.                   |1    |NULL    |529  |
# |Comair Inc.                              |1    |0.0     |14424|
# |Republic Airlines                        |6    |0.0     |20548|
# |Endeavor Air Inc.                        |6    |NULL    |1363 |
# |Capital Cargo International              |6    |1.0     |1071 |
# |Horizon Air                              |1    |0.0     |5942 |
# |Delta Air Lines Inc.                     |1    |1.0     |10105|
# |Hawaiian Airlines Inc.                   |1    |0.0     |4628 |
# |Southwest Airlines Co.                   |1    |0.0     |70981|
# |Endeavor Air Inc.                        |6    |0.0     |15427|
# |Spirit Air Lines                         |1    |1.0     |3627 |
# |Frontier Airlines Inc.                   |1    |0.0     |8373 |
# |Horizon Air                              |1    |NULL    |399  |
# |Alaska Airlines Inc.                     |6    |1.0     |3254 |
# |American Airlines Inc.                   |6    |NULL    |4552 |
# |Capital Cargo International              |6    |NULL    |103  |
# |Mesa Airlines Inc.                       |6    |1.0     |2183 |
# |JetBlue Airways                          |6    |1.0     |7510 |
# |Delta Air Lines Inc.                     |1    |NULL    |2220 |
# |American Airlines Inc.                   |6    |0.0     |48713|
# |Southwest Airlines Co.                   |1    |1.0     |20016|
# |Capital Cargo International              |1    |NULL    |619  |
# |Capital Cargo International              |1    |1.0     |1345 |
# |GoJet Airlines, LLC d/b/a United Express |1    |1.0     |1202 |
# |Air Wisconsin Airlines Corp              |1    |1.0     |1351 |
# |Mesa Airlines Inc.                       |1    |NULL    |1445 |
# |JetBlue Airways                          |1    |NULL    |2063 |
# |Air Wisconsin Airlines Corp              |1    |0.0     |4135 |
# |American Airlines Inc.                   |3    |1.0     |11930|
# |Capital Cargo International              |3    |0.0     |6970 |
# |United Air Lines Inc.                    |3    |NULL    |198  |
# |Envoy Air                                |3    |0.0     |19077|
# |Delta Air Lines Inc.                     |3    |NULL    |422  |
# |Comair Inc.                              |3    |NULL    |342  |
# |Allegiant Air                            |3    |0.0     |7290 |
# |Alaska Airlines Inc.                     |3    |1.0     |2819 |
# |Hawaiian Airlines Inc.                   |3    |1.0     |777  |
# |JetBlue Airways                          |3    |0.0     |14805|
# |American Airlines Inc.                   |3    |0.0     |58598|
# |Capital Cargo International              |3    |1.0     |903  |
# |JetBlue Airways                          |3    |NULL    |614  |
# |Endeavor Air Inc.                        |3    |NULL    |336  |
# |Hawaiian Airlines Inc.                   |3    |0.0     |5209 |
# |Envoy Air                                |3    |1.0     |3115 |
# |Frontier Airlines Inc.                   |3    |1.0     |4779 |
# |Hawaiian Airlines Inc.                   |3    |NULL    |23   |
# |Endeavor Air Inc.                        |3    |1.0     |2935 |
# |Southwest Airlines Co.                   |3    |NULL    |2025 |
# |Commutair Aka Champlain Enterprises, Inc.|3    |0.0     |5018 |
# |Southwest Airlines Co.                   |3    |0.0     |69430|
# |Republic Airlines                        |3    |NULL    |794  |
# |GoJet Airlines, LLC d/b/a United Express |3    |NULL    |119  |
# |Air Wisconsin Airlines Corp              |3    |0.0     |5492 |
# |Mesa Airlines Inc.                       |3    |1.0     |1550 |
# |GoJet Airlines, LLC d/b/a United Express |3    |0.0     |4023 |
# |Republic Airlines                        |3    |1.0     |5260 |
# |Commutair Aka Champlain Enterprises, Inc.|3    |NULL    |88   |
# |Mesa Airlines Inc.                       |3    |NULL    |96   |
# |GoJet Airlines, LLC d/b/a United Express |3    |1.0     |1099 |
# |Mesa Airlines Inc.                       |3    |0.0     |8170 |
# |Commutair Aka Champlain Enterprises, Inc.|3    |1.0     |1002 |
# |Air Wisconsin Airlines Corp              |3    |NULL    |34   |
# |Air Wisconsin Airlines Corp              |3    |1.0     |793  |
# |Southwest Airlines Co.                   |3    |1.0     |32265|
# +-----------------------------------------+-----+--------+-----+

# %% [markdown]
# ## Revisión de Particionamiento

# %%
def filtrar_por_mes_y_aerolinea(df, mes=None, aerolinea=None):
    if mes is not None:
        df = df.filter(col("Month") == mes)
    if aerolinea is not None:
        df = df.filter(col("Airline") == aerolinea)
    return df

# %%
# Obtener los valores únicos de mes y aerolínea
meses = [row['Month'] for row in df.select("Month").distinct().collect()]
aerolineas = [row['Airline'] for row in df.select("Airline").distinct().collect()]

# %%
# Iterar sobre todas las combinaciones
for mes in meses:
    print(f"\n🔎 Filtrando: Mes = {mes}")
    df_filtrado = filtrar_por_mes_y_aerolinea(df, mes=mes, aerolinea=None)
    df_filtrado.show(5, truncate=False)
# Out:
# 🔎 Filtrando: Mes = 4
# +----------+-----------------------------------------+------+----+---------+--------+----------+-------+---------------+--------+-------+---------------+-------+--------------+-----------------+--------+----+-------+-----+----------+---------+-------------------------+---------------------------------------+------------------------+---------------------------+-------------------------------+-----------------+------------------------+---------------------------+-----------+-------------------------------+---------------+------------------+------------------+------------------------+-----------+---------------+---------------+---------+-------------+----------------+----------------+-------------------+---------+-------------+-------------+-------+--------+--------------------+----------+-------+---------+--------+------+----------+--------+--------+------------------+----------+-------------+------------------+
# |FlightDate|Airline                                  |Origin|Dest|Cancelled|Diverted|CRSDepTime|DepTime|DepDelayMinutes|DepDelay|ArrTime|ArrDelayMinutes|AirTime|CRSElapsedTime|ActualElapsedTime|Distance|Year|Quarter|Month|DayofMonth|DayOfWeek|Marketing_Airline_Network|Operated_or_Branded_Code_Share_Partners|DOT_ID_Marketing_Airline|IATA_Code_Marketing_Airline|Flight_Number_Marketing_Airline|Operating_Airline|DOT_ID_Operating_Airline|IATA_Code_Operating_Airline|Tail_Number|Flight_Number_Operating_Airline|OriginAirportID|OriginAirportSeqID|OriginCityMarketID|OriginCityName          |OriginState|OriginStateFips|OriginStateName|OriginWac|DestAirportID|DestAirportSeqID|DestCityMarketID|DestCityName       |DestState|DestStateFips|DestStateName|DestWac|DepDel15|DepartureDelayGroups|DepTimeBlk|TaxiOut|WheelsOff|WheelsOn|TaxiIn|CRSArrTime|ArrDelay|ArrDel15|ArrivalDelayGroups|ArrTimeBlk|DistanceGroup|DivAirportLandings|
# +----------+-----------------------------------------+------+----+---------+--------+----------+-------+---------------+--------+-------+---------------+-------+--------------+-----------------+--------+----+-------+-----+----------+---------+-------------------------+---------------------------------------+------------------------+---------------------------+-------------------------------+-----------------+------------------------+---------------------------+-----------+-------------------------------+---------------+------------------+------------------+------------------------+-----------+---------------+---------------+---------+-------------+----------------+----------------+-------------------+---------+-------------+-------------+-------+--------+--------------------+----------+-------+---------+--------+------+----------+--------+--------+------------------+----------+-------------+------------------+
# |2022-04-04|Commutair Aka Champlain Enterprises, Inc.|GJT   |DEN |false    |false   |1133      |1123.0 |0.0            |-10.0   |1228.0 |0.0            |40.0   |72.0          |65.0             |212.0   |2022|2      |4    |4         |1        |UA                       |UA_CODESHARE                           |19977                   |UA                         |
# |2022-03-22|Delta Air Lines Inc.|TYS   |ATL |false    |false   |1600      |1545.0 |0.0            |-15.0   |1646.0 |0.0            |36.0   |64.0          |61.0             |152.0   |2022|1      |3    |22        |2        |DL                       |DL                                     |19790                   |DL                         |471                            |DL               |19790                   |DL                         |N938AT     |471                            |15412          |1541205           |35412             |Knoxville, TN  |TN         |47             |Tennessee      |54       |10397        |1039707         |30397           |Atlanta, GA        |GA       |13           |Georgia      |34     |0.0     |-1.0                |1600-1659 |16.0   |1601.0   |1637.0  |9.0   |1704      |-18.0   |0.0     |-2.0              |1700-1759 |1            |0                 |
# +----------+--------------------+------+----+---------+--------+----------+-------+---------------+--------+-------+---------------+-------+--------------+-----------------+--------+----+-------+-----+----------+---------+-------------------------+---------------------------------------+------------------------+---------------------------+-------------------------------+-----------------+------------------------+---------------------------+-----------+-------------------------------+---------------+------------------+------------------+---------------+-----------+---------------+---------------+---------+-------------+----------------+----------------+-------------------+---------+-------------+-------------+-------+--------+--------------------+----------+-------+---------+--------+------+----------+--------+--------+------------------+----------+-------------+------------------+
# only showing top 5 rows

# %%
for aerolinea in aerolineas:
    print(f"\n🔎 Filtrando:  Aerolínea = {aerolinea}")
    df_filtrado = filtrar_por_mes_y_aerolinea(df, mes=None, aerolinea=aerolinea)
    df_filtrado.show(5, truncate=False)
# Out:
# 🔎 Filtrando:  Aerolínea = GoJet Airlines, LLC d/b/a United Express
# +----------+----------------------------------------+------+----+---------+--------+----------+-------+---------------+--------+-------+---------------+-------+--------------+-----------------+--------+----+-------+-----+----------+---------+-------------------------+---------------------------------------+------------------------+---------------------------+-------------------------------+-----------------+------------------------+---------------------------+-----------+-------------------------------+---------------+------------------+------------------+--------------+-----------+---------------+---------------+---------+-------------+----------------+----------------+----------------+---------+-------------+--------------+-------+--------+--------------------+----------+-------+---------+--------+------+----------+--------+--------+------------------+----------+-------------+------------------+
# |FlightDate|Airline                                 |Origin|Dest|Cancelled|Diverted|CRSDepTime|DepTime|DepDelayMinutes|DepDelay|ArrTime|ArrDelayMinutes|AirTime|CRSElapsedTime|ActualElapsedTime|Distance|Year|Quarter|Month|DayofMonth|DayOfWeek|Marketing_Airline_Network|Operated_or_Branded_Code_Share_Partners|DOT_ID_Marketing_Airline|IATA_Code_Marketing_Airline|Flight_Number_Marketing_Airline|Operating_Airline|DOT_ID_Operating_Airline|IATA_Code_Operating_Airline|Tail_Number|Flight_Number_Operating_Airline|OriginAirportID|OriginAirportSeqID|OriginCityMarketID|OriginCityName|OriginState|OriginStateFips|OriginStateName|OriginWac|DestAirportID|DestAirportSeqID|DestCityMarketID|DestCityName    |DestState|DestStateFips|DestStateName |DestWac|DepDel15|DepartureDelayGroups|DepTimeBlk|TaxiOut|WheelsOff|WheelsOn|TaxiIn|CRSArrTime|ArrDelay|ArrDel15|ArrivalDelayGroups|ArrTimeBlk|DistanceGroup|DivAirportLandings|
# +----------+----------------------------------------+------+----+---------+--------+----------+-------+---------------+--------+-------+---------------+-------+--------------+-----------------+--------+----+-------+-----+----------+---------+-------------------------+---------------------------------------+------------------------+---------------------------+-------------------------------+-----------------+------------------------+---------------------------+-----------+-------------------------------+---------------+------------------+------------------+--------------+-----------+---------------+---------------+---------+-------------+----------------+----------------+----------------+---------+-------------+--------------+-------+--------+--------------------+----------+-------+---------+--------+------+----------+--------+--------+------------------+----------+-------------+------------------+
# |2022-04-04|GoJet Airlines, LLC d/b/a United Express|EWR   |DCA |false    |false   |1435      |1433.0 |0.0            |-2.0    |1550.0 |0.0            |46.0   |76.0          |77.0             |199.0   |2022|2      |4    |4         |1        |UA                       |UA_CODESHARE                           |19977                   |UA                         |4194                           |G7               |20500                   |G7                         |N559GJ     |4194                           |11618          |1161802           |31703             |Newark, NJ    |NJ         |34             |New Jersey     |21       |11278        |1127805         |30852           |Washington, DC  |VA       |51           |Virginia      |38     |0.0     |-1.0                |1400-1459 |21.0   |1454.0   |1540.0  |10.0  |1551      |-1.0    |0.0     |-1.0              |1500-1559 |1            |0                 |
# |2022-04-04|GoJet Airlines, LLC d/b/a United Express|EWR   |DCA |false    |false   |1130      |1125.0 |0.0            |-5.0    |1223.0 |0.0            |41.0   |76.0          |58.0             |199.0   |2022|2      |4    |4         |1        |UA                       |UA_CODESHARE                           |19977                   |UA                         |4193                           |G7               |20500                   |G7                         |N562GJ     |4193                           |11618          |1161802           |31703             |Newark, NJ    |NJ         |34             |New Jersey     |21       |11278        |1127805         |30852           |Washington, DC  |VA       |51           |Virginia      |38     |0.0     |-1.0                |1100-1159 |12.0   |1137.0   |1218.0  |5.0   |1246      |-23.0   |0.0     |-2.0              |1200-1259 |1            |0                 |
# |2022-04-04|GoJet Airlines, LLC d/b/a United Express|EWR   |DCA |false    |false   |959       |954.0  |0.0            |-5.0    |1112.0 |0.0            |48.0   |83.0          |78.0             |199.0   |2022|2      |4    |4         |1        |UA                       |UA_CODESHARE                           |19977                   |UA                         |4192                           |G7               |20500                   |G7                         |N559GJ     |4192                           |11618          |1161802           |31703             |Newark, NJ    |NJ         |34             |New Jersey     |21       |11278        |1127805         |30852           |Washington, DC  |VA       |51           |Virginia      |38     |0.0     |-1.0                |0900-0959 |18.0   |1012.0   |1100.0  |12.0  |1122      |-10.0   |0.0     |-1.0              |1100-1159 |1            |0                 |
# |2022-04-04|GoJet Airlines, LLC d/b/a United Express|EWR   |IND |false    |false   |1035      |1030.0 |0.0            |-5.0    |1251.0 |5.0            |106.0  |131.0         |141.0            |645.0   |2022|2      |4    |4         |1        |UA                       |UA_CODESHARE                           |19977                   |UA                         |4190                           |G7               |20500                   |G7                         |N542GJ     |4190                           |11618          |1161802           |31703             |Newark, NJ    |NJ         |34             |New Jersey     |21       |12339        |1233904         |32337           |Indianapolis, IN|IN       |18           |Indiana       |42     |0.0     |-1.0                |1000-1059 |31.0   |1101.0   |1247.0  |4.0   |1246      |5.0     |0.0     |0.0               |1200-1259 |3            |0                 |
# |2022-04-04|GoJet Airlines, LLC d/b/a United Express|EWR   |CLT |false    |false   |1310      |1302.0 |0.0            |-8.0    |1453.0 |0.0            |88.0   |117.0         |111.0            |529.0   |2022|2      |4    |4         |1        |UA                       |UA_CODESHARE                           |19977                   |UA                         |4189                           |G7               |20500                   |G7                         |N578GJ     |4189                           |11618          |1161802           |31703             |Newark, NJ    |NJ         |34             |New Jersey     |21       |11057        |1105703         |31057           |Charlotte, NC   |NC       |37           |North Carolina|36     |0.0     |-1.0                |1300-1359 |13.0   |1315.0   |1443.0  |10.0  |1507      |-14.0   |0.0     |-1.0              |1500-1559 |3            |0                 |
# +----------+----------------------------------------+------+----+---------+--------+----------+-------+---------------+--------+-------+---------------+-------+--------------+-----------------+--------+----+-------+-----+----------+---------+-------------------------+---------------------------------------+------------------------+---------------------------+-------------------------------+-----------------+------------------------+---------------------------+-----------+-------------------------------+---------------+------------------+------------------+--------------+-----------+---------------+---------------+---------+-------------+----------------+----------------+----------------+---------+-------------+--------------+-------+--------+--------------------+----------+-------+---------+--------+------+----------+--------+--------+------------------+----------+-------------+------------------+
# only showing top 5 rows
#
#
# 🔎 Filtrando:  Aerolínea = Endeavor Air Inc.
# +----------+-----------------+------+----+---------+--------+----------+-------+---------------+--------+-------+---------------+-------+--------------+-----------------+--------+----+-------+-----+----------+---------+-------------------------+---------------------------------------+------------------------+---------------------------+-------------------------------+-----------------+------------------------+---------------------------+-----------+-------------------------------+---------------+------------------+------------------+--------------+-----------+---------------+---------------+---------+-------------+----------------+----------------+------------------+---------+-------------+--------------+-------+--------+--------------------+----------+-------+---------+--------+------+----------+--------+--------+------------------+----------+-------------+------------------+
# |FlightDate|Air
K     |1                              |11697          |1169706           |32467             |Fort Lauderdale, FL|FL         |12             |Florida        |33       |13930        |1393007         |30977           |Chicago, IL |IL       |17           |Illinois     |41     |1.0     |12.0                |2100-2159 |18.0   |229.0    |412.0   |9.0   |2359      |262.0   |1.0     |12.0              |2300-2359 |5            |0                 |
# |2022-04-04|Spirit Air Lines|FLL   |ORD |false    |false   |2147      |2227.0 |40.0           |40.0    |39.0   |40.0           |157.0  |192.0         |192.0            |1182.0  |2022|2      |4    |4         |1        |NK                       |NK                                     |20416                   |NK                         |1                              |NK               |20416                   |NK                         |N680NK     |1                              |11697          |1169706           |32467             |Fort Lauderdale, FL|FL         |12             |Florida        |33       |13930        |1393007         |30977           |Chicago, IL |IL       |17           |Illinois     |41     |1.0     |2.0                 |2100-2159 |25.0   |2252.0   |29.0    |10.0  |2359      |40.0    |1.0     |2.0               |2300-2359 |5            |0                 |
# |2022-04-05|Spirit Air Lines|FLL   |ORD |false    |false   |2200      |2252.0 |52.0           |52.0    |58.0   |46.0           |164.0  |192.0         |186.0            |1182.0  |2022|2      |4    |5         |2        |NK                       |NK                                     |20416                   |NK                         |1                              |NK               |20416                   |NK                         |N681NK     |1                              |11697          |1169706           |32467             |Fort Lauderdale, FL|FL         |12             |Florida        |33       |13930        |1393007         |30977           |Chicago, IL |IL       |17           |Illinois     |41     |1.0     |3.0                 |2200-2259 |13.0   |2305.0   |49.0    |9.0   |12        |46.0    |1.0     |3.0               |0001-0559 |5            |0                 |
# +----------+----------------+------+----+---------+--------+----------+-------+---------------+--------+-------+---------------+-------+--------------+-----------------+--------+----+-------+-----+----------+---------+-------------------------+---------------------------------------+------------------------+---------------------------+-------------------------------+-----------------+------------------------+---------------------------+-----------+-------------------------------+---------------+------------------+------------------+-------------------+-----------+---------------+---------------+---------+-------------+----------------+----------------+------------+---------+-------------+-------------+-------+--------+--------------------+----------+-------+---------+--------+------+----------+--------+--------+------------------+----------+-------------+------------------+
# only showing top 5 rows

# %%
# Iterar sobre todas las combinaciones
for mes in meses:
    for aerolinea in aerolineas:
        print(f"\n🔎 Filtrando: Mes = {mes}, Aerolínea = {aerolinea}")
        df_filtrado = filtrar_por_mes_y_aerolinea(df, mes=mes, aerolinea=aerolinea)
        df_filtrado.show(5, truncate=False)
# Out:
# 🔎 Filtrando: Mes = 4, Aerolínea = GoJet Airlines, LLC d/b/a United Express
# +----------+----------------------------------------+------+----+---------+--------+----------+-------+---------------+--------+-------+---------------+-------+--------------+-----------------+--------+----+-------+-----+----------+---------+-------------------------+---------------------------------------+------------------------+---------------------------+-------------------------------+-----------------+------------------------+---------------------------+-----------+-------------------------------+---------------+------------------+------------------+--------------+-----------+---------------+---------------+---------+-------------+----------------+----------------+----------------+---------+-------------+--------------+-------+--------+--------------------+----------+-------+---------+--------+------+----------+--------+--------+------------------+----------+-------------+------------------+
# |FlightDate|Airline                                 |Origin|Dest|Cancelled|Diverted|CRSDepTime|DepTime|DepDelayMinutes|DepDelay|ArrTime|ArrDelayMinutes|AirTime|CRSElapsedTime|ActualElapsedTime|Distance|Year|Quarter|Month|DayofMonth|DayOfWeek|Marketing_Airline_Network|Operated_or_Branded_Code_Share_Partners|DOT_ID_Marketing_Airline|IATA_Code_Marketing_Airline|Flight_Number_Marketing_Airline|Operating_Airline|DOT_ID_Operating_Airline|IATA_Code_Operating_Airline|Tail_Number|Flight_Number_Operating_Airline|OriginAirportID|OriginAirportSeqID|OriginCityMarketID|OriginCityName|OriginState|OriginStateFips|OriginStateName|OriginWac|DestAirportID|DestAirportSeqID|DestCityMarketID|DestCityName    |DestState|DestStateFips|DestStateName |DestWac|DepDel15|DepartureDelayGroups|DepTimeBlk|TaxiOut|WheelsOff|WheelsOn|TaxiIn|CRSArrTime|ArrDelay|ArrDel15|ArrivalDelayGroups|ArrTimeBlk|DistanceGroup|DivAirportLandings|
# +----------+----------------------------------------+------+----+---------+--------+----------+-------+---------------+--------+-------+---------------+-------+--------------+-----------------+--------+----+-------+-----+----------+---------+-------------------------+---------------------------------------+------------------------+---------------------------+-------------------------------+-----------------+------------------------+---------------------------+-----------+-------------------------------+---------------+------------------+------------------+--------------+-----------+---------------+---------------+---------+-------------+----------------+----------------+----------------+---------+-------------+--------------+-------+--------+--------------------+----------+-------+---------+--------+------+----------+--------+--------+------------------+----------+-------------+------------------+
# |2022-04-04|GoJet Airlines, LLC d/b/a United Express|EWR   |DCA |false    |false   |1435      |1433.0 |0.0            |-2.0    |1550.0 |0.0            |46.0   |76.0          |77.0             |199.0   |2022|2      |4    |4         |1        |UA                       |UA_CODESHARE                           |19977                   |UA                         |4194                           |G7               |20500                   |G7                         |N559GJ     |4194                           |11618          |1161802           |31703             |Newark, NJ    |NJ         |34             |New Jersey     |21       |11278        |1127805         |30852           |Washington, DC  |VA       |51           |Virginia      |38     |0.0     |-1.0                |1400-1459 |21.0   |1454.0   |1540.0  |10.0  |1551      |-1.0    |0.0     |-1.0              |1500-1559 |1            |0                 |
# |2022-04-04|GoJet Airlines, LLC d/b/a United Express|EWR   |DCA |false    |false   |1130      |1125.0 |0.0            |-5.0    |1223.0 |0.0            |41.0   |76.0          |58.0             |199.0   |2022|2      |4    |4         |1        |UA                       |UA_CODESHARE                           |19977                   |UA                         |4193                           |G7               |20500                   |G7                         |N562GJ     |4193                           |11618          |1161802           |31703             |Newark, NJ    |NJ         |34             |New Jersey     |21       |11278        |1127805         |30852           |Washington, DC  |VA       |51           |Virginia      |38     |0.0     |-1.0                |1100-1159 |12.0   |1137.0   |1218.0  |5.0   |1246      |-23.0   |0.0     |-2.0              |1200-1259 |1            |0                 |
# |2022-04-04|GoJet Airlines, LLC d/b/a United Express|EWR   |DCA |false    |false   |959       |954.0  |0.0            |-5.0    |1112.0 |0.0            |48.0   |83.0          |78.0             |199.0   |2022|2      |4    |4         |1        |UA                       |UA_CODESHARE                           |19977                   |UA                         |4192                           |G7               |20500                   |G7                         |N559GJ     |4192                           |11618          |1161802           |31703             |Newark, NJ    |NJ         |34             |New Jersey     |21       |11278        |1127805         |30852           |Washington, DC  |VA       |51           |Virginia      |38     |0.0     |-1.0                |0900-0959 |18.0   |1012.0   |1100.0  |12.0  |1122      |-10.0   |0.0     |-1.0              |1100-1159 |1            |0                 |
# |2022-04-04|GoJet Airlines, LLC d/b/a United Express|EWR   |IND |false    |false   |1035      |1030.0 |0.0            |-5.0    |1251.0 |5.0            |106.0  |131.0         |141.0            |645.0   |2022|2      |4    |4         |1        |UA                       |UA_CODESHARE                           |19977                   |UA                         |4190                           |G7               |20500                   |G7                         |N542GJ     |4190                           |11618          |1161802           |31703             |Newark, NJ    |NJ         |34             |New Jersey     |21       |12339        |1233904         |32337           |Indianapolis, IN|IN       |18           |Indiana       |42     |0.0     |-1.0                |1000-1059 |31.0   |1101.0   |1247.0  |4.0   |1246      |5.0     |0.0     |0.0               |1200-1259 |3            |0                 |
# |2022-04-04|GoJet Airlines, LLC d/b/a United Express|EWR   |CLT |false    |false   |1310      |1302.0 |0.0            |-8.0    |1453.0 |0.0            |88.0   |117.0         |111.0            |529.0   |2022|2      |4    |4         |1        |UA                       |UA_CODESHARE                           |19977                   |UA                         |
+------+----+---------+--------+----------+-------+---------------+--------+-------+---------------+-------+--------------+-----------------+--------+----+-------+-----+----------+---------+-------------------------+---------------------------------------+------------------------+---------------------------+-------------------------------+-----------------+------------------------+---------------------------+-----------+-------------------------------+---------------+------------------+------------------+--------------+-----------+---------------+---------------+---------+-------------+----------------+----------------+--------------+---------+-------------+-------------+-------+--------+--------------------+----------+-------+---------+--------+------+----------+--------+--------+------------------+----------+-------------+------------------+
# only showing top 5 rows
#
#
# 🔎 Filtrando: Mes = 3, Aerolínea = Spirit Air Lines
# +----------+----------------+------+----+---------+--------+----------+-------+---------------+--------+-------+---------------+-------+--------------+-----------------+--------+----+-------+-----+----------+---------+-------------------------+---------------------------------------+------------------------+---------------------------+-------------------------------+-----------------+------------------------+---------------------------+-----------+-------------------------------+---------------+------------------+------------------+-------------------+-----------+---------------+---------------+---------+-------------+----------------+----------------+------------+---------+-------------+-------------+-------+--------+--------------------+----------+-------+---------+--------+------+----------+--------+--------+------------------+----------+-------------+------------------+
# |FlightDate|Airline         |Origin|Dest|Cancelled|Diverted|CRSDepTime|DepTime|DepDelayMinutes|DepDelay|ArrTime|ArrDelayMinutes|AirTime|CRSElapsedTime|ActualElapsedTime|Distance|Year|Quarter|Month|DayofMonth|DayOfWeek|Marketing_Airline_Network|Operated_or_Branded_Code_Share_Partners|DOT_ID_Marketing_Airline|IATA_Code_Marketing_Airline|Flight_Number_Marketing_Airline|Operating_Airline|DOT_ID_Operating_Airline|IATA_Code_Operating_Airline|Tail_Number|Flight_Number_Operating_Airline|OriginAirportID|OriginAirportSeqID|OriginCityMarketID|OriginCityName     |OriginState|OriginStateFips|OriginStateName|OriginWac|DestAirportID|DestAirportSeqID|DestCityMarketID|DestCityName|DestState|DestStateFips|DestStateName|DestWac|DepDel15|DepartureDelayGroups|DepTimeBlk|TaxiOut|WheelsOff|WheelsOn|TaxiIn|CRSArrTime|ArrDelay|ArrDel15|ArrivalDelayGroups|ArrTimeBlk|DistanceGroup|DivAirportLandings|
# +----------+----------------+------+----+---------+--------+----------+-------+---------------+--------+-------+---------------+-------+--------------+-----------------+--------+----+-------+-----+----------+---------+-------------------------+---------------------------------------+------------------------+---------------------------+-------------------------------+-----------------+------------------------+---------------------------+-----------+-------------------------------+---------------+------------------+------------------+-------------------+-----------+---------------+---------------+---------+-------------+----------------+----------------+------------+---------+-------------+-------------+-------+--------+--------------------+----------+-------+---------+--------+------+----------+--------+--------+------------------+----------+-------------+------------------+
# |2022-03-01|Spirit Air Lines|FLL   |ORD |false    |false   |2215      |2241.0 |26.0           |26.0    |53.0   |28.0           |169.0  |190.0         |192.0            |1182.0  |2022|1      |3    |1         |2        |NK                       |NK                                     |20416                   |NK                         |1                              |NK               |20416                   |NK                         |N675NK     |1                              |11697          |1169706           |32467             |Fort Lauderdale, FL|FL         |12             |Florida        |33       |13930        |1393007         |30977           |Chicago, IL |IL       |17           |Illinois     |41     |1.0     |1.0                 |2200-2259 |12.0   |2253.0   |42.0    |11.0  |25        |28.0    |1.0     |1.0               |0001-0559 |5            |0                 |
# |2022-03-02|Spirit Air Lines|FLL   |ORD |false    |false   |2215      |2212.0 |0.0            |-3.0    |23.0   |0.0            |169.0  |190.0         |191.0            |1182.0  |2022|1      |3    |2         |3        |NK                       |NK                                     |20416                   |NK                         |1                              |NK               |20416                   |NK                         |N686NK     |1                              |11697          |1169706           |32467             |Fort Lauderdale, FL|FL         |12             |Florida        |33       |13930        |1393007         |30977           |Chicago, IL |IL       |17           |Illinois     |41     |0.0     |-1.0                |2200-2259 |12.0   |2224.0   |13.0    |10.0  |25        |-2.0    |0.0     |-1.0              |0001-0559 |5            |0                 |
# |2022-03-03|Spirit Air Lines|FLL   |ORD |false    |false   |2215      |2326.0 |71.0           |71.0    |140.0  |75.0           |172.0  |190.0         |194.0            |1182.0  |2022|1      |3    |3         |4        |NK                       |NK                                     |20416                   |NK                         |1                              |NK               |20416                   |NK                         |N673NK     |1                              |11697          |1169706           |32467             |Fort Lauderdale, FL|FL         |12             |Florida        |33       |13930        |1393007         |30977           |Chicago, IL |IL       |17           |Illinois     |41     |1.0     |4.0                 |2200-2259 |12.0   |2338.0   |130.0   |10.0  |25        |75.0    |1.0     |5.0               |0001-0559 |5            |0                 |
# |2022-03-04|Spirit Air Lines|FLL   |ORD |false    |false   |2215      |2211.0 |0.0            |-4.0    |17.0   |0.0            |169.0  |190.0         |186.0            |1182.0  |2022|1      |3    |4         |5        |NK                       |NK                                     |20416                   |NK                         |1                              |NK               |20416                   |NK                         |N674NK     |1                              |11697          |1169706           |32467             |Fort Lauderdale, FL|FL         |12             |Florida        |33       |13930        |1393007         |30977           |Chicago, IL |IL       |17           |Illinois     |41     |0.0     |-1.0                |2200-2259 |11.0   |2222.0   |11.0    |6.0   |25        |-8.0    |0.0     |-1.0              |0001-0559 |5            |0                 |
# |2022-03-05|Spirit Air Lines|FLL   |ORD |false    |false   |2215      |2215.0 |0.0            |0.0     |101.0  |36.0           |193.0  |190.0         |226.0            |1182.0  |2022|1      |3    |5         |6        |NK                       |NK                                     |20416                   |NK                         |1                              |NK               |20416                   |NK                         |N677NK     |1                              |11697          |1169706           |32467             |Fort Lauderdale, FL|FL         |12             |Florida        |33       |13930        |1393007         |30977           |Chicago, IL |IL       |17           |Illinois     |41     |0.0     |0.0                 |2200-2259 |13.0   |2228.0   |41.0    |20.0  |25        |36.0    |1.0     |2.0               |0001-0559 |5            |0                 |
# +----------+----------------+------+----+---------+--------+----------+-------+---------------+--------+-------+---------------+-------+--------------+-----------------+--------+----+-------+-----+----------+---------+-------------------------+---------------------------------------+------------------------+---------------------------+-------------------------------+-----------------+------------------------+---------------------------+-----------+-------------------------------+---------------+------------------+------------------+-------------------+-----------+---------------+---------------+---------+-------------+----------------+----------------+------------+---------+-------------+-------------+-------+--------+--------------------+----------+-------+---------+--------+------+----------+--------+--------+------------------+----------+-------------+------------------+
# only showing top 5 rows

# %% [markdown]
# #"Selección de los Datos
# Para esta sección, aplicaremos muestreo estratificado proporcional basado en las variables "Airline" y "DepDel15".

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from functools import reduce # Import the standard library reduce

# Crear una sesión de Spark
spark = SparkSession.builder.appName("StratifiedSampling").getOrCreate()

# Cargar datos
# Change the file path to the correct CSV file
data = spark.read.csv("/content/drive/MyDrive/Big Data/Copia de Combined_Flights_2022.csv", header=True, inferSchema=True)

# Calcular el número total de filas en el conjunto de datos
total_count = data.count()

# Contar el número de filas por aerolínea y retraso
strata_counts = data.groupBy("Airline", "DepDel15").count()

# Definir el porcentaje de muestreo
sampling_fraction = 0.1  # 10% de muestreo

# Calcular el número de muestras que se deben tomar de cada estrato
strata_counts = strata_counts.withColumn("sample_size", (F.col("count") * sampling_fraction).cast("int"))

# Función para muestrear desde cada estrato
def stratified_sample(df, strata_cols, sample_size_col):
    strata_values = df.select(strata_cols).distinct().collect()
    sampled_dfs = []

    for row in strata_values:
        # Correctly combine filters using the bitwise AND operator
        filters = [df[col] == row[col] for col in strata_cols]
        # Use the standard library's reduce to combine the filter conditions
        combined_filter = reduce(lambda x, y: x & y, filters)
        strata_df = df.filter(combined_filter)

        # Ensure sample_size is not greater than the actual number of rows in the stratum
        current_strata_count = strata_df.count()
        # Find the sample size for the current stratum from strata_counts DataFrame
        sample_size_row = strata_counts.filter(combined_filter).select(sample_size_col).first()
        # Handle cases where the stratum might not be in strata_counts (though unlikely with distinct values)
        sample_size = sample_size_row[0] if sample_size_row else 0

        sample_size = min(sample_size, current_strata_count) # Added this line

        # Adjust fraction calculation to handle potential sample_size being 0 or greater than available rows
        fraction_to_sample = sample_size / current_strata_count if current_strata_count > 0 else 0.0
        # Ensure fraction is not greater than 1.0 (although min(1.0, ...) handles this)
        # Added .limit(sample_size) as an alternative way to sample a fixed number of rows
        sampled_strata = strata_df.sample(fraction=min(1.0, fraction_to_sample), seed=42).limit(sample_size)

        sampled_dfs.append(sampled_strata)

    # Handle the case where sampled_dfs might be empty
    if not sampled_dfs:
        return spark.createDataFrame([], df.schema) # Return an empty DataFrame with the same schema

    # Union all the sampled DataFrames
    # Use reduce with unionAll for cleaner code
    return reduce(lambda df1, df2: df1.unionAll(df2), sampled_dfs)


# Aplicar el muestreo estratificado
sampled_data = stratified_sample(data, ["Airline", "DepDel15"], "sample_size")

# Mostrar la muestra final
sampled_data.show()
# Out:
# +----------+---------+------+----+---------+--------+----------+-------+---------------+--------+-------+---------------+-------+--------------+-----------------+--------+----+-------+-----+----------+---------+-------------------------+---------------------------------------+------------------------+---------------------------+-------------------------------+-----------------+------------------------+---------------------------+-----------+-------------------------------+---------------+------------------+------------------+--------------------+-----------+---------------+---------------+---------+-------------+----------------+----------------+--------------------+---------+-------------+-------------+-------+--------+--------------------+----------+-------+---------+--------+------+----------+--------+--------+------------------+----------+-------------+------------------+
# |FlightDate|  Airline|Origin|Dest|Cancelled|Diverted|CRSDepTime|DepTime|DepDelayMinutes|DepDelay|ArrTime|ArrDelayMinutes|AirTime|CRSElapsedTime|ActualElapsedTime|Distance|Year|Quarter|Month|DayofMonth|DayOfWeek|Marketing_Airline_Network|Operated_or_Branded_Code_Share_Partners|DOT_ID_Marketing_Airline|IATA_Code_Marketing_Airline|Flight_Number_Marketing_Airline|Operating_Airline|DOT_ID_Operating_Airline|IATA_Code_Operating_Airline|Tail_Number|Flight_Number_Operating_Airline|OriginAirportID|OriginAirportSeqID|OriginCityMarketID|      OriginCityName|OriginState|OriginStateFips|OriginStateName|OriginWac|DestAirportID|DestAirportSeqID|DestCityMarketID|        DestCityName|DestState|DestStateFips|DestStateName|DestWac|DepDel15|DepartureDelayGroups|DepTimeBlk|TaxiOut|WheelsOff|WheelsOn|TaxiIn|CRSArrTime|ArrDelay|ArrDel15|ArrivalDelayGroups|ArrTimeBlk|DistanceGroup|DivAirportLandings|
# +----------+---------+------+----+---------+--------+----------+-------+---------------+--------+-------+---------------+-------+--------------+-----------------+--------+----+-------+-----+----------+---------+-------------------------+---------------------------------------+------------------------+---------------------------+-------------------------------+-----------------+------------------------+---------------------------+-----------+-------------------------------+---------------+------------------+------------------+--------------------+-----------+---------------+---------------+---------+-------------+----------------+----------------+--------------------+---------+-------------+-------------+-------+--------+--------------------+----------+-------+---------+--------+------+----------+--------+--------+------------------+----------+-------------+------------------+
# |2022-04-08|Envoy Air|   GCK| DFW|    false|   false|       600|  555.0|            0.0|    -5.0|  722.0|            0.0|   62.0|          85.0|             87.0|   404.0|2022|      2|    4|         8|        5|                       AA|                           AA_CODESHARE|                   19805|                         AA|                           3500|               MQ|                   20398|                         MQ|     N612AE|                           3500|          11867|           1186703|             31867|     Garden City, KS|         KS|             20|         Kansas|       62|        11298|         1129806|           30194|Dallas/Fort Worth...|       TX|           48|        Texas|     74|     0.0|                -1.0| 0600-0659|   15.0|    610.0|   712.0|  10.0|       725|    -3.0|     0.0|              -1.0| 0700-0759|            2|                 0|
# |2022-04-17|Envoy Air|   GCK| DFW|    false|   false|       600|  555.0|            0.0|    -5.0|  718.0|            0.0|   65.0|          85.0|             83.0|   404.0|2022|      2|    4|        17|        7|                       AA|                           AA_CODESHARE|                   19805|                         AA|                           3500|               MQ|                   20398|                         MQ|     N677AE|                           3500|          11867|           1186703|             31867|     Garden City, KS|         KS|             20|         Kansas|       62|        11298|         1129806|           30194|Dallas/Fort Worth...|       TX|           48|        Texas|     74|     0.0|                -1.0| 0600-0659|   10.0|    605.0|   710.0|   8.0|       725|    -7.0|     0.0|              -1.0| 0700-0759|            2|                 0|
# |2022-04-19|Envoy Air|   GCK| DFW|    false|   false|       600|  558.0|            0.0|    -2.0|  719.0|            0.0|   61.0|          85.0|             81.0|   404.0|2022|      2|    4|        19|        2|                       AA|                           AA_CODESHARE|                   19805|                         AA|                           
# |2022-04-25|Envoy Air|   DFW| MSN|    false|   false|      2040| 2037.0|            0.0|    -3.0| 2233.0|            0.0|   93.0|         137.0|            116.0|   821.0|2022|      2|    4|        25|        1|                       AA|                           AA_CODESHARE|                   19805|                         AA|                           3507|               MQ|                   20398|                         MQ|     N204NN|                           3507|          11298|           1129806|             30194|Dallas/Fort Worth...|         TX|             48|          Texas|       74|        13485|         1348502|           33485|         Madison, WI|       WI|           55|    Wisconsin|     45|     0.0|                -1.0| 2000-2059|   15.0|   2052.0|  2225.0|   8.0|      2257|   -24.0|     0.0|              -2.0| 2200-2259|            4|                 0|
# +----------+---------+------+----+---------+--------+----------+-------+---------------+--------+-------+---------------+-------+--------------+-----------------+--------+----+-------+-----+----------+---------+-------------------------+---------------------------------------+------------------------+---------------------------+-------------------------------+-----------------+------------------------+---------------------------+-----------+-------------------------------+---------------+------------------+------------------+--------------------+-----------+---------------+---------------+---------+-------------+----------------+----------------+--------------------+---------+-------------+-------------+-------+--------+--------------------+----------+-------+---------+--------+------+----------+--------+--------+------------------+----------+-------------+------------------+
# only showing top 20 rows

# %% [markdown]
# ##Preparación de los Datos
#
# En esta etapa, preprocesamos la muestra M para corregir valores nulos y transformar tipos de datos:

# %%
# Corrección de valores nulos
cleaned_data = sampled_data.na.fill({"DepDelayMinutes": 0})

# Identificación y eliminación de valores atípicos
cleaned_data = cleaned_data.filter(cleaned_data['Distance'] <= 3000)

# Transformación de tipos de datos
from pyspark.sql.types import IntegerType

cleaned_data = cleaned_data.withColumn("DepDelayMinutes", cleaned_data["DepDelayMinutes"].cast(IntegerType()))

# %% [markdown]
# ##Preparación del Conjunto de Entrenamiento y Prueba
# Dividimos la muestra M en conjuntos de entrenamiento y prueba usando una división 80/20:

# %%
# División de los datos en conjunto de entrenamiento y prueba
train_data, test_data = cleaned_data.randomSplit([0.8, 0.2], seed=42)
print("Entrenamiento:", train_data.count(), "Prueba:", test_data.count())

# %% [markdown]
# ##Construcción de Modelos de Aprendizaje Supervisado y No Supervisado
# Aprendizaje Supervisado
# Entrenamos un modelo RandomForestClassifier:

# %%
from pyspark.ml.classification import RandomForestClassifier
from pyspark.ml.feature import VectorAssembler

# Preparar los datos de entrada
feature_columns = ['Distance', 'DayOfWeek', 'CRSDepTime']
assembler = VectorAssembler(inputCols=feature_columns, outputCol="features")
train_data = assembler.transform(train_data)

# Entrenar el modelo
rf = RandomForestClassifier(labelCol="DepDel15", featuresCol="features")
model = rf.fit(train_data)

# Predicciones
predictions = model.transform(test_data)
predictions.select("DepDel15", "prediction").show()

# %% [markdown]
# ##Aprendizaje No Supervisado
# Entrenamos un modelo KMeans:

# %%
from pyspark.ml.clustering import KMeans

# Preparar los datos de entrada
kmeans_data = assembler.transform(cleaned_data)

# Entrenar el modelo KMeans
kmeans = KMeans(k=3, seed=1)
model = kmeans.fit(kmeans_data)

# Predicciones
predictions = model.transform(kmeans_data)
predictions.select("features", "prediction").show()

# %% [markdown]
# ## Conclusiones
#
# La actividad de aplicar algoritmos de aprendizaje supervisado y no supervisado utilizando PySpark ha sido exitosa, logrando implementar un modelo de Random Forest para predecir retrasos significativos en vuelos y un modelo de K-Means para identificar patrones de agrupamiento entre aerolíneas. A través del muestreo estratificado proporcional, se aseguró una representación adecuada de las diferentes categorías de aerolíneas y clases de retraso, lo que minimizó sesgos en el análisis. La preparación de datos, que incluyó la limpieza y transformación de tipos, mejoró la calidad del conjunto analizado, lo que se tradujo en resultados más fiables. Los modelos desarrollados no solo proporcionaron insights valiosos sobre el comportamiento de los vuelos, sino que también establecieron una base sólida para análisis futuros, destacando la importancia de la documentación y el ajuste de modelos para optimizar el rendimiento en aplicaciones prácticas.
